# %% [markdown]
# # Content
# 1. Fine-tunning models
#     * [Fine-tunning BERT for NER](fine-tunning/Custom_Named_Entity_Recognition_with_BERT_only_first_wordpiece.ipynb) - Considering the first wordpiece only
#     * [Fine-tunning BERT for NER (v2)](fine-tunning/Custom_Named_Entity_Recognition_with_BERT.ipynb) - Up-to-date version that also uses pipeline for inference.
#
#     You can use either one of the above versions, but the second one (v2) is probably recommended.
# 2. More soon ...
